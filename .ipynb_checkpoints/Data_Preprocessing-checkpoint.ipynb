# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import resample
import re
import string
from pyvi import ViUtils
from sklearn.feature_extraction.text import TfidfVectorizer
from underthesea import word_tokenize
from joblib import Parallel, delayed
import multiprocessing
import emoji

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
sns.set_theme(style="whitegrid")
print("Import thành công")
# Out:
# Import thành công

# %%
path = os.path.join('data', 'raw', 'data.csv')
df = pd.read_csv(path)
print('Đọc dữ liệu thành công')
# Out:
# Đọc dữ liệu thành công

# %%
df.head()
# Out:
#                       content label  start
# 0               Áo bao đẹp ạ!   POS      5
# 1                   Tuyệt vời   POS      5
# 2   2day ao khong giong trong   NEG      1
# 3  Mùi thơm,bôi lên da mềm da   POS      5
# 4            Vải đẹp, dày dặn   POS      5

# %%
df.tail()
# Out:
#                                                  content label  start
# 31455                                    Không đáng tiền   NEG      1
# 31456                                       Quần rất đẹp   POS      5
# 31457                             Hàng đẹp đúng giá tiền   POS      5
# 31458                                    Chất vải khá ổn   POS      4
# 31459  áo rất ok nhé , vải mịn , len cao cổ này phối ...   POS      5

# %%
print(type(df.columns))
print(type(df.index))
# Out:
# <class 'pandas.Index'>
# <class 'pandas.RangeIndex'>

# %%
print(df.dtypes)
# Out:
# content      str
# label        str
# start      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# content    24
# label       0
# start       0
# dtype: int64

# %%
df.describe()
# Out:
#               start
# count  31460.000000
# mean       3.736840
# std        1.382483
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000

# %%
df = df.dropna(subset=['content', 'label', 'start'])

# %%
def to_lowercase(text):
    text = str(text).lower()
    return text

# %%
def remove_all_tag(sentence):
    """Remove tags added from reading files"""
    return re.sub(r'\n|\t|\r', ' ', sentence)

# %%
def remove_emoji(text):
    if not isinstance(text, str):
        return ""
    text = emoji.replace_emoji(text, replace='')
    return text

# %%
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

# %%
def load_teencode_dict(path):
    teencode_dict = {}

    with open(path, 'r', encoding='utf-8') as f:
        for line in f:
            key, value = line.strip().split('\t')
            teencode_dict[key] = value

    return teencode_dict

# %%
teencode_dict = load_teencode_dict('dicts/teencode.txt')

# %%
def convert_teencode(text, teencode_dict):
    words = text.split()
    new_words = []

    for word in words:
        if word in teencode_dict:
            new_words.append(teencode_dict[word])
        else:
            new_words.append(word)

    return " ".join(new_words)

# %%
def remove_duplicate_letters(text):
    return " ".join(
        re.sub(r'(.)\1+', r'\1', w) if len(w) > 5 else w
        for w in text.split()
    )

# %%
def remove_punctuation(text):
    return re.sub(r'[^\w\sÀ-ỹ]', ' ', text)

# %%
def remove_nonsense_words(text):
    vowels = "aeiouyàáạảãăắằẳẵặâấầẩẫậèéẹẻẽêếềểễệìíịỉĩòóọỏõôốồổỗộơớờởỡợùúụủũưứừửữự"

    words = text.split()
    clean_words = []

    for w in words:

        # bỏ từ quá dài
        if len(w) > 20:
            continue

        # kiểm tra tỷ lệ nguyên âm
        vowel_count = sum(1 for c in w if c in vowels)
        if len(w) > 6 and vowel_count / len(w) < 0.2:
            continue

        clean_words.append(w)

    return " ".join(clean_words)

# %%
def clean_text(text):
    text = to_lowercase(text)

    text = remove_all_tag(text)
    text = remove_emoji(text)
    text = remove_numbers(text)

    text = remove_duplicate_letters(text)

    # thay dấu câu bằng khoảng trắng
    text = remove_punctuation(text)

    text = convert_teencode(text, teencode_dict)

    # chuẩn hóa khoảng trắng trước khi tokenize
    text = re.sub(r'\s+', ' ', text).strip()

    # bỏ từ rác
    text = remove_nonsense_words(text)

    return text

# %%
results = Parallel(n_jobs=6, backend="loky", batch_size=200, verbose=0)(
    delayed(clean_text)(text) for text in df['content']
)

# Gán kết quả và làm sạch DataFrame
df['clean_content'] = results

df = df.dropna(subset=['clean_content'])
df = df[df['clean_content'].str.strip() != ""].copy()

df[['content', 'clean_content']].head(10)
# Out:
#                              content                            clean_content
# 0                      Áo bao đẹp ạ!                             áo bao đẹp ạ
# 1                          Tuyệt vời                                tuyệt vời
# 2          2day ao khong giong trong                 day ao không giong trong
# 3         Mùi thơm,bôi lên da mềm da               mùi thơm bôi lên da mềm da
# 4                   Vải đẹp, dày dặn                          vải đẹp dày dặn
# 5     Hàng rất đẹp, rất chi là ưng ý            hàng rất đẹp rất chi là ưng ý
# 6  Chất lượng sản phẩm tốt, date dài  chất lượng sản phẩm tốt hạn sử dụng dài
# 7      Ăn nói và thái độ phục vụ tốt            ăn nói và thái độ phục vụ tốt
# 8        Đóng gói sản phẩm chắc chắn              đóng gói sản phẩm chắc chắn
# 9  tất sờn hết ca chưa dùng mà vay r      tất sờn hết ca chưa dùng mà vay rồi

# %%
output_path = os.path.join('data', 'processed', 'data_clean.csv')
os.makedirs(os.path.dirname(output_path), exist_ok=True)

df.to_csv(output_path, index=False)

print("Đã lưu dataset")
# Out:
# Đã lưu dataset
