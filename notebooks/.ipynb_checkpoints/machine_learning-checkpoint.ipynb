# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from underthesea import word_tokenize
from IPython.display import display, Markdown
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV

from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

# %%
# =========================
# LOAD DATA
# =========================
data_path = "../data/processed/"

train_df = pd.read_excel(os.path.join(data_path, "train.xlsx"))
dev_df   = pd.read_excel(os.path.join(data_path, "dev.xlsx"))
test_df  = pd.read_excel(os.path.join(data_path, "test.xlsx"))

X_train_raw = train_df["clean_review"]
y_train = train_df["label"]

X_dev_raw = dev_df["clean_review"]
y_dev = dev_df["label"]

X_test_raw = test_df["clean_review"]
y_test = test_df["label"]

print("Train size:", len(X_train_raw))
print("Dev size:", len(X_dev_raw))
print("Test size:", len(X_test_raw))
# Out:
# Train size: 20762
# Dev size: 4455
# Test size: 4438

# %%
# =========================
# LOAD STOPWORDS
# =========================
stopwords_path = os.path.join("..", "dicts", "vietnamese-stopwords.txt")

with open(stopwords_path, "r", encoding="utf-8") as f:
    stopwords = set([line.strip() for line in f])

print("Number of stopwords:", len(stopwords))
# Out:
# Number of stopwords: 1942

# %%
# =========================
# PREPROCESS FUNCTION
# =========================
def preprocess_text(text):
    if not isinstance(text, str):
        return ""
    
    # 1. Tách từ (underthesea)
    text = word_tokenize(text, format="text")
    
    # 2. Xóa stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stopwords]
    
    return " ".join(tokens)

# %%
# =========================
# APPLY PREPROCESSING
# =========================
X_train = X_train_raw.apply(preprocess_text)
X_dev   = X_dev_raw.apply(preprocess_text)
X_test  = X_test_raw.apply(preprocess_text)

# Xem thử kết quả
print("Before:", X_train_raw.iloc[0])
print("After :", X_train.iloc[0])
# Out:
# Before: đèn như c lắp không quảng cáo lắp xe c về lắp đéo vừa làm ăn như ứt
# After : đèn c_lắp quảng_cáo lắp xe c lắp_đéo làm_ăn ứt

# %%
# =========================
# TF-IDF VECTORIZATION
# =========================
vectorizer = TfidfVectorizer(
    max_features=20000,
    ngram_range=(1, 2),
    norm='l2'
)

X_train_tfidf = vectorizer.fit_transform(X_train)
X_dev_tfidf   = vectorizer.transform(X_dev)
X_test_tfidf  = vectorizer.transform(X_test)

print("TF-IDF shape:", X_train_tfidf.shape)
# Out:
# TF-IDF shape: (20762, 20000)

# %%
# =========================
# NAIVE BAYES
# =========================
nb_params = {"alpha": [0.01, 0.1, 0.5, 1.0]}

nb_grid = GridSearchCV(
    MultinomialNB(),
    nb_params,
    cv=5,
    scoring="f1_macro",
    n_jobs=-1
)

nb_grid.fit(X_train_tfidf, y_train)
nb_best = nb_grid.best_estimator_

print("Best NB params:", nb_grid.best_params_)
# Out:
# Best NB params: {'alpha': 0.1}

# %%
# =========================
# VISUALIZE NB
# =========================
import matplotlib.pyplot as plt

alphas = nb_grid.cv_results_['param_alpha'].data
scores = nb_grid.cv_results_['mean_test_score']

plt.figure()
plt.plot(alphas, scores, marker='o')

plt.xlabel("Alpha")
plt.ylabel("Macro F1 (CV)")
plt.title("Naive Bayes - Hyperparameter Tuning")

for i in range(len(alphas)):
    plt.text(alphas[i], scores[i], f"{scores[i]:.3f}")

plt.show()

# %%
# =========================
# SVM
# =========================
svm_params = {"C": [0.1, 1, 10]}

svm_grid = GridSearchCV(
    LinearSVC(),
    svm_params,
    cv=5,
    scoring="f1_macro",
    n_jobs=-1
)

svm_grid.fit(X_train_tfidf, y_train)
svm_best = svm_grid.best_estimator_

print("Best SVM params:", svm_grid.best_params_)
# Out:
# Best SVM params: {'C': 1}

# %%
# =========================
# VISUALIZE SVM
# =========================
C_values = svm_grid.cv_results_['param_C'].data
scores = svm_grid.cv_results_['mean_test_score']

plt.figure()
plt.plot(C_values, scores, marker='o')

plt.xlabel("C")
plt.ylabel("Macro F1 (CV)")
plt.title("SVM - Hyperparameter Tuning")

for i in range(len(C_values)):
    plt.text(C_values[i], scores[i], f"{scores[i]:.3f}")

plt.show()

# %%
# =========================
# RANDOM FOREST
# =========================
rf_params = {
    "n_estimators": [20, 50, 100, 200],
    "max_depth": [None, 10, 20]
}

rf_grid = GridSearchCV(
    RandomForestClassifier(random_state=42),
    rf_params,
    cv=5,
    scoring="f1_macro",
    n_jobs=-1
)

rf_grid.fit(X_train_tfidf, y_train)
rf_best = rf_grid.best_estimator_

print("Best RF params:", rf_grid.best_params_)
# Out:
# Best RF params: {'max_depth': None, 'n_estimators': 50}

# %%
# =========================
# VISUALIZE RANDOM FOREST 
# =========================
results = pd.DataFrame(rf_grid.cv_results_)

# lọc max_depth = None (thực chất là NaN)
filtered = results[results['param_max_depth'].isna()]

# convert kiểu dữ liệu
n_estimators = filtered['param_n_estimators'].astype(int)
scores = filtered['mean_test_score']

plt.figure()
plt.plot(n_estimators, scores, marker='o')

plt.xlabel("n_estimators")
plt.ylabel("Macro F1 (CV)")
plt.title("Random Forest (max_depth=None)")

for i in range(len(n_estimators)):
    plt.text(n_estimators.iloc[i], scores.iloc[i], f"{scores.iloc[i]:.3f}")

plt.show()

# %%
# =========================
# PROFESSIONAL EVALUATION FUNCTION
# =========================
def evaluate(model, X, y, name="Model"):
    y_pred = model.predict(X)

    acc = accuracy_score(y, y_pred)
    f1  = f1_score(y, y_pred, average="macro")

    # Title đẹp
    display(Markdown(f"## {name} Evaluation"))

    # ===== Summary Table =====
    summary_df = pd.DataFrame({
        "Metric": ["Accuracy", "Macro F1"],
        "Score": [round(acc, 4), round(f1, 4)]
    })

    display(summary_df.style.set_caption("Overall Performance"))

    # ===== Classification Report =====
    report = classification_report(y, y_pred, output_dict=True)
    report_df = pd.DataFrame(report).transpose()

    display(report_df.style
            .set_caption("Classification Report")
            .format("{:.4f}"))

    # ===== Confusion Matrix =====
    cm = confusion_matrix(y, y_pred)

    labels = sorted(list(set(y)))  # hoặc tự set: ["Negative","Neutral","Positive"]

    plt.figure()
    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        xticklabels=labels,
        yticklabels=labels
    )

    plt.title(f"Confusion Matrix - {name}")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")

    plt.show()

# %%
# =========================
# EVALUATE ON DEV
# =========================
evaluate(nb_best, X_dev_tfidf, y_dev, "Naive Bayes (Dev)")
# Out:
# ## Naive Bayes (Dev) Evaluation
# <style type="text/css">
# </style>
# <table id="T_310cc">
#   <caption>Overall Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_310cc_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_310cc_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_310cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_310cc_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_310cc_row0_col1" class="data row0 col1" >0.696100</td>
#     </tr>
#     <tr>
#       <th id="T_310cc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_310cc_row1_col0" class="data row1 col0" >Macro F1</td>
#       <td id="T_310cc_row1_col1" class="data row1 col1" >0.667300</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_cfb56">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfb56_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_cfb56_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_cfb56_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_cfb56_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfb56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cfb56_row0_col0" class="data row0 col0" >0.7159</td>
#       <td id="T_cfb56_row0_col1" class="data row0 col1" >0.7324</td>
#       <td id="T_cfb56_row0_col2" class="data row0 col2" >0.7241</td>
#       <td id="T_cfb56_row0_col3" class="data row0 col3" >1562.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cfb56_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cfb56_row1_col0" class="data row1 col0" >0.5337</td>
#       <td id="T_cfb56_row1_col1" class="data row1 col1" >0.4527</td>
#       <td id="T_cfb56_row1_col2" class="data row1 col2" >0.4899</td>
#       <td id="T_cfb56_row1_col3" class="data row1 col3" >1120.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cfb56_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cfb56_row2_col0" class="data row2 col0" >0.7604</td>
#       <td id="T_cfb56_row2_col1" class="data row2 col1" >0.8178</td>
#       <td id="T_cfb56_row2_col2" class="data row2 col2" >0.7880</td>
#       <td id="T_cfb56_row2_col3" class="data row2 col3" >1773.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cfb56_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_cfb56_row3_col0" class="data row3 col0" >0.6961</td>
#       <td id="T_cfb56_row3_col1" class="data row3 col1" >0.6961</td>
#       <td id="T_cfb56_row3_col2" class="data row3 col2" >0.6961</td>
#       <td id="T_cfb56_row3_col3" class="data row3 col3" >0.6961</td>
#     </tr>
#     <tr>
#       <th id="T_cfb56_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_cfb56_row4_col0" class="data row4 col0" >0.6700</td>
#       <td id="T_cfb56_row4_col1" class="data row4 col1" >0.6676</td>
#       <td id="T_cfb56_row4_col2" class="data row4 col2" >0.6673</td>
#       <td id="T_cfb56_row4_col3" class="data row4 col3" >4455.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cfb56_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_cfb56_row5_col0" class="data row5 col0" >0.6878</td>
#       <td id="T_cfb56_row5_col1" class="data row5 col1" >0.6961</td>
#       <td id="T_cfb56_row5_col2" class="data row5 col2" >0.6906</td>
#       <td id="T_cfb56_row5_col3" class="data row5 col3" >4455.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate(svm_best, X_dev_tfidf, y_dev, "SVM (Dev)")
# Out:
# ## SVM (Dev) Evaluation
# <style type="text/css">
# </style>
# <table id="T_8c44f">
#   <caption>Overall Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c44f_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_8c44f_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c44f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c44f_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_8c44f_row0_col1" class="data row0 col1" >0.690900</td>
#     </tr>
#     <tr>
#       <th id="T_8c44f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8c44f_row1_col0" class="data row1 col0" >Macro F1</td>
#       <td id="T_8c44f_row1_col1" class="data row1 col1" >0.660500</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_10d2a">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10d2a_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_10d2a_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_10d2a_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_10d2a_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10d2a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10d2a_row0_col0" class="data row0 col0" >0.7010</td>
#       <td id="T_10d2a_row0_col1" class="data row0 col1" >0.7458</td>
#       <td id="T_10d2a_row0_col2" class="data row0 col2" >0.7227</td>
#       <td id="T_10d2a_row0_col3" class="data row0 col3" >1562.0000</td>
#     </tr>
#     <tr>
#       <th id="T_10d2a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_10d2a_row1_col0" class="data row1 col0" >0.5408</td>
#       <td id="T_10d2a_row1_col1" class="data row1 col1" >0.4321</td>
#       <td id="T_10d2a_row1_col2" class="data row1 col2" >0.4804</td>
#       <td id="T_10d2a_row1_col3" class="data row1 col3" >1120.0000</td>
#     </tr>
#     <tr>
#       <th id="T_10d2a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_10d2a_row2_col0" class="data row2 col0" >0.7529</td>
#       <td id="T_10d2a_row2_col1" class="data row2 col1" >0.8060</td>
#       <td id="T_10d2a_row2_col2" class="data row2 col2" >0.7785</td>
#       <td id="T_10d2a_row2_col3" class="data row2 col3" >1773.0000</td>
#     </tr>
#     <tr>
#       <th id="T_10d2a_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_10d2a_row3_col0" class="data row3 col0" >0.6909</td>
#       <td id="T_10d2a_row3_col1" class="data row3 col1" >0.6909</td>
#       <td id="T_10d2a_row3_col2" class="data row3 col2" >0.6909</td>
#       <td id="T_10d2a_row3_col3" class="data row3 col3" >0.6909</td>
#     </tr>
#     <tr>
#       <th id="T_10d2a_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_10d2a_row4_col0" class="data row4 col0" >0.6649</td>
#       <td id="T_10d2a_row4_col1" class="data row4 col1" >0.6613</td>
#       <td id="T_10d2a_row4_col2" class="data row4 col2" >0.6605</td>
#       <td id="T_10d2a_row4_col3" class="data row4 col3" >4455.0000</td>
#     </tr>
#     <tr>
#       <th id="T_10d2a_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_10d2a_row5_col0" class="data row5 col0" >0.6814</td>
#       <td id="T_10d2a_row5_col1" class="data row5 col1" >0.6909</td>
#       <td id="T_10d2a_row5_col2" class="data row5 col2" >0.6840</td>
#       <td id="T_10d2a_row5_col3" class="data row5 col3" >4455.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate(rf_best, X_dev_tfidf, y_dev, "Random Forest (Dev)")
# Out:
# ## Random Forest (Dev) Evaluation
# <style type="text/css">
# </style>
# <table id="T_960cf">
#   <caption>Overall Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_960cf_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_960cf_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_960cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_960cf_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_960cf_row0_col1" class="data row0 col1" >0.687100</td>
#     </tr>
#     <tr>
#       <th id="T_960cf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_960cf_row1_col0" class="data row1 col0" >Macro F1</td>
#       <td id="T_960cf_row1_col1" class="data row1 col1" >0.643600</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_715a2">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_715a2_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_715a2_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_715a2_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_715a2_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_715a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_715a2_row0_col0" class="data row0 col0" >0.6824</td>
#       <td id="T_715a2_row0_col1" class="data row0 col1" >0.7663</td>
#       <td id="T_715a2_row0_col2" class="data row0 col2" >0.7220</td>
#       <td id="T_715a2_row0_col3" class="data row0 col3" >1562.0000</td>
#     </tr>
#     <tr>
#       <th id="T_715a2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_715a2_row1_col0" class="data row1 col0" >0.5997</td>
#       <td id="T_715a2_row1_col1" class="data row1 col1" >0.3438</td>
#       <td id="T_715a2_row1_col2" class="data row1 col2" >0.4370</td>
#       <td id="T_715a2_row1_col3" class="data row1 col3" >1120.0000</td>
#     </tr>
#     <tr>
#       <th id="T_715a2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_715a2_row2_col0" class="data row2 col0" >0.7183</td>
#       <td id="T_715a2_row2_col1" class="data row2 col1" >0.8342</td>
#       <td id="T_715a2_row2_col2" class="data row2 col2" >0.7719</td>
#       <td id="T_715a2_row2_col3" class="data row2 col3" >1773.0000</td>
#     </tr>
#     <tr>
#       <th id="T_715a2_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_715a2_row3_col0" class="data row3 col0" >0.6871</td>
#       <td id="T_715a2_row3_col1" class="data row3 col1" >0.6871</td>
#       <td id="T_715a2_row3_col2" class="data row3 col2" >0.6871</td>
#       <td id="T_715a2_row3_col3" class="data row3 col3" >0.6871</td>
#     </tr>
#     <tr>
#       <th id="T_715a2_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_715a2_row4_col0" class="data row4 col0" >0.6668</td>
#       <td id="T_715a2_row4_col1" class="data row4 col1" >0.6481</td>
#       <td id="T_715a2_row4_col2" class="data row4 col2" >0.6436</td>
#       <td id="T_715a2_row4_col3" class="data row4 col3" >4455.0000</td>
#     </tr>
#     <tr>
#       <th id="T_715a2_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_715a2_row5_col0" class="data row5 col0" >0.6759</td>
#       <td id="T_715a2_row5_col1" class="data row5 col1" >0.6871</td>
#       <td id="T_715a2_row5_col2" class="data row5 col2" >0.6702</td>
#       <td id="T_715a2_row5_col3" class="data row5 col3" >4455.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# =========================
# EVALUATE ON TEST
# =========================
evaluate(nb_best, X_test_tfidf, y_test, "Naive Bayes (Test)")
# Out:
# ## Naive Bayes (Test) Evaluation
# <style type="text/css">
# </style>
# <table id="T_82115">
#   <caption>Overall Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82115_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_82115_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82115_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_82115_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_82115_row0_col1" class="data row0 col1" >0.674900</td>
#     </tr>
#     <tr>
#       <th id="T_82115_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_82115_row1_col0" class="data row1 col0" >Macro F1</td>
#       <td id="T_82115_row1_col1" class="data row1 col1" >0.642600</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_0d660">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d660_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_0d660_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_0d660_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_0d660_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d660_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d660_row0_col0" class="data row0 col0" >0.6853</td>
#       <td id="T_0d660_row0_col1" class="data row0 col1" >0.7248</td>
#       <td id="T_0d660_row0_col2" class="data row0 col2" >0.7045</td>
#       <td id="T_0d660_row0_col3" class="data row0 col3" >1559.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0d660_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d660_row1_col0" class="data row1 col0" >0.5006</td>
#       <td id="T_0d660_row1_col1" class="data row1 col1" >0.4073</td>
#       <td id="T_0d660_row1_col2" class="data row1 col2" >0.4492</td>
#       <td id="T_0d660_row1_col3" class="data row1 col3" >1117.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0d660_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d660_row2_col0" class="data row2 col0" >0.7500</td>
#       <td id="T_0d660_row2_col1" class="data row2 col1" >0.8002</td>
#       <td id="T_0d660_row2_col2" class="data row2 col2" >0.7743</td>
#       <td id="T_0d660_row2_col3" class="data row2 col3" >1762.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0d660_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_0d660_row3_col0" class="data row3 col0" >0.6749</td>
#       <td id="T_0d660_row3_col1" class="data row3 col1" >0.6749</td>
#       <td id="T_0d660_row3_col2" class="data row3 col2" >0.6749</td>
#       <td id="T_0d660_row3_col3" class="data row3 col3" >0.6749</td>
#     </tr>
#     <tr>
#       <th id="T_0d660_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_0d660_row4_col0" class="data row4 col0" >0.6453</td>
#       <td id="T_0d660_row4_col1" class="data row4 col1" >0.6441</td>
#       <td id="T_0d660_row4_col2" class="data row4 col2" >0.6426</td>
#       <td id="T_0d660_row4_col3" class="data row4 col3" >4438.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0d660_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_0d660_row5_col0" class="data row5 col0" >0.6645</td>
#       <td id="T_0d660_row5_col1" class="data row5 col1" >0.6749</td>
#       <td id="T_0d660_row5_col2" class="data row5 col2" >0.6679</td>
#       <td id="T_0d660_row5_col3" class="data row5 col3" >4438.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate(svm_best, X_test_tfidf, y_test, "SVM (Test)")
# Out:
# ## SVM (Test) Evaluation
# <style type="text/css">
# </style>
# <table id="T_9c9e7">
#   <caption>Overall Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c9e7_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_9c9e7_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c9e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c9e7_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_9c9e7_row0_col1" class="data row0 col1" >0.667900</td>
#     </tr>
#     <tr>
#       <th id="T_9c9e7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c9e7_row1_col0" class="data row1 col0" >Macro F1</td>
#       <td id="T_9c9e7_row1_col1" class="data row1 col1" >0.634200</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e5c15">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5c15_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_e5c15_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_e5c15_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_e5c15_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5c15_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5c15_row0_col0" class="data row0 col0" >0.6714</td>
#       <td id="T_e5c15_row0_col1" class="data row0 col1" >0.7300</td>
#       <td id="T_e5c15_row0_col2" class="data row0 col2" >0.6994</td>
#       <td id="T_e5c15_row0_col3" class="data row0 col3" >1559.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e5c15_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5c15_row1_col0" class="data row1 col0" >0.4971</td>
#       <td id="T_e5c15_row1_col1" class="data row1 col1" >0.3894</td>
#       <td id="T_e5c15_row1_col2" class="data row1 col2" >0.4367</td>
#       <td id="T_e5c15_row1_col3" class="data row1 col3" >1117.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e5c15_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e5c15_row2_col0" class="data row2 col0" >0.7446</td>
#       <td id="T_e5c15_row2_col1" class="data row2 col1" >0.7894</td>
#       <td id="T_e5c15_row2_col2" class="data row2 col2" >0.7664</td>
#       <td id="T_e5c15_row2_col3" class="data row2 col3" >1762.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e5c15_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_e5c15_row3_col0" class="data row3 col0" >0.6679</td>
#       <td id="T_e5c15_row3_col1" class="data row3 col1" >0.6679</td>
#       <td id="T_e5c15_row3_col2" class="data row3 col2" >0.6679</td>
#       <td id="T_e5c15_row3_col3" class="data row3 col3" >0.6679</td>
#     </tr>
#     <tr>
#       <th id="T_e5c15_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_e5c15_row4_col0" class="data row4 col0" >0.6377</td>
#       <td id="T_e5c15_row4_col1" class="data row4 col1" >0.6363</td>
#       <td id="T_e5c15_row4_col2" class="data row4 col2" >0.6342</td>
#       <td id="T_e5c15_row4_col3" class="data row4 col3" >4438.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e5c15_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_e5c15_row5_col0" class="data row5 col0" >0.6566</td>
#       <td id="T_e5c15_row5_col1" class="data row5 col1" >0.6679</td>
#       <td id="T_e5c15_row5_col2" class="data row5 col2" >0.6599</td>
#       <td id="T_e5c15_row5_col3" class="data row5 col3" >4438.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate(rf_best, X_test_tfidf, y_test, "Random Forest (Test)")
# Out:
# ## Random Forest (Test) Evaluation
# <style type="text/css">
# </style>
# <table id="T_72c89">
#   <caption>Overall Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72c89_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_72c89_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72c89_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72c89_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_72c89_row0_col1" class="data row0 col1" >0.673100</td>
#     </tr>
#     <tr>
#       <th id="T_72c89_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72c89_row1_col0" class="data row1 col0" >Macro F1</td>
#       <td id="T_72c89_row1_col1" class="data row1 col1" >0.627900</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_3a26b">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a26b_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_3a26b_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_3a26b_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_3a26b_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a26b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a26b_row0_col0" class="data row0 col0" >0.6714</td>
#       <td id="T_3a26b_row0_col1" class="data row0 col1" >0.7601</td>
#       <td id="T_3a26b_row0_col2" class="data row0 col2" >0.7130</td>
#       <td id="T_3a26b_row0_col3" class="data row0 col3" >1559.0000</td>
#     </tr>
#     <tr>
#       <th id="T_3a26b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a26b_row1_col0" class="data row1 col0" >0.5748</td>
#       <td id="T_3a26b_row1_col1" class="data row1 col1" >0.3232</td>
#       <td id="T_3a26b_row1_col2" class="data row1 col2" >0.4138</td>
#       <td id="T_3a26b_row1_col3" class="data row1 col3" >1117.0000</td>
#     </tr>
#     <tr>
#       <th id="T_3a26b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a26b_row2_col0" class="data row2 col0" >0.7046</td>
#       <td id="T_3a26b_row2_col1" class="data row2 col1" >0.8178</td>
#       <td id="T_3a26b_row2_col2" class="data row2 col2" >0.7570</td>
#       <td id="T_3a26b_row2_col3" class="data row2 col3" >1762.0000</td>
#     </tr>
#     <tr>
#       <th id="T_3a26b_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_3a26b_row3_col0" class="data row3 col0" >0.6731</td>
#       <td id="T_3a26b_row3_col1" class="data row3 col1" >0.6731</td>
#       <td id="T_3a26b_row3_col2" class="data row3 col2" >0.6731</td>
#       <td id="T_3a26b_row3_col3" class="data row3 col3" >0.6731</td>
#     </tr>
#     <tr>
#       <th id="T_3a26b_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_3a26b_row4_col0" class="data row4 col0" >0.6503</td>
#       <td id="T_3a26b_row4_col1" class="data row4 col1" >0.6337</td>
#       <td id="T_3a26b_row4_col2" class="data row4 col2" >0.6279</td>
#       <td id="T_3a26b_row4_col3" class="data row4 col3" >4438.0000</td>
#     </tr>
#     <tr>
#       <th id="T_3a26b_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_3a26b_row5_col0" class="data row5 col0" >0.6603</td>
#       <td id="T_3a26b_row5_col1" class="data row5 col1" >0.6731</td>
#       <td id="T_3a26b_row5_col2" class="data row5 col2" >0.6552</td>
#       <td id="T_3a26b_row5_col3" class="data row5 col3" >4438.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# =========================
# COMPARISON TABLE
# =========================
results = []

models = {
    "Naive Bayes": nb_best,
    "SVM": svm_best,
    "Random Forest": rf_best
}

for name, model in models.items():
    y_pred = model.predict(X_test_tfidf)
    
    acc = accuracy_score(y_test, y_pred)
    f1  = f1_score(y_test, y_pred, average="macro")
    
    results.append({
        "Model": name,
        "Accuracy": round(acc, 4),
        "Macro F1": round(f1, 4)
    })

results_df = pd.DataFrame(results)
results_df = results_df.sort_values(by="Macro F1", ascending=False)

results_df
# Out:
#            Model  Accuracy  Macro F1
# 0    Naive Bayes    0.6749    0.6426
# 1            SVM    0.6679    0.6342
# 2  Random Forest    0.6731    0.6279

# %%
models = results_df["Model"]
accuracy = results_df["Accuracy"]
f1_scores = results_df["Macro F1"]

x = np.arange(len(models))
width = 0.35

plt.figure()

plt.bar(x - width/2, accuracy, width, label="Accuracy")
plt.bar(x + width/2, f1_scores, width, label="Macro F1")

plt.xticks(x, models)
plt.ylabel("Score")
plt.title("Model Comparison")

# Hiển thị số
for i in range(len(models)):
    plt.text(x[i] - width/2, accuracy[i], f"{accuracy[i]:.3f}")
    plt.text(x[i] + width/2, f1_scores[i], f"{f1_scores[i]:.3f}")

plt.legend()
plt.show()

# %%
# =========================
# SAVE RESULTS
# =========================
results_df.to_excel("model_comparison.xlsx", index=False)
