# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from underthesea import word_tokenize
from IPython.display import display, Markdown
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV

from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

# %%
# =========================
# LOAD DATA
# =========================
data_path = "../data/processed/"

train_df = pd.read_excel(os.path.join(data_path, "train.xlsx"))
dev_df   = pd.read_excel(os.path.join(data_path, "dev.xlsx"))
test_df  = pd.read_excel(os.path.join(data_path, "test.xlsx"))

X_train_raw = train_df["clean_review"]
y_train = train_df["label"]

X_dev_raw = dev_df["clean_review"]
y_dev = dev_df["label"]

X_test_raw = test_df["clean_review"]
y_test = test_df["label"]

print("Train size:", len(X_train_raw))
print("Dev size:", len(X_dev_raw))
print("Test size:", len(X_test_raw))
# Out:
# Train size: 20591
# Dev size: 4417
# Test size: 4431

# %%
# =========================
# LOAD STOPWORDS
# =========================
stopwords_path = os.path.join("..", "dicts", "vietnamese-stopwords.txt")

with open(stopwords_path, "r", encoding="utf-8") as f:
    stopwords = set([line.strip() for line in f])

print("Number of stopwords:", len(stopwords))
# Out:
# Number of stopwords: 1942

# %%
# =========================
# PREPROCESS FUNCTION
# =========================
def preprocess_text(text):
    if not isinstance(text, str):
        return ""
    
    # 1. Tách từ (underthesea)
    text = word_tokenize(text, format="text")
    
    # 2. Xóa stopwords
    tokens = text.split()
    tokens = [word for word in tokens if word not in stopwords]
    
    return " ".join(tokens)

# %%
# =========================
# APPLY PREPROCESSING
# =========================
X_train = X_train_raw.apply(preprocess_text)
X_dev   = X_dev_raw.apply(preprocess_text)
X_test  = X_test_raw.apply(preprocess_text)

# Xem thử kết quả
print("Before:", X_train_raw.iloc[0])
print("After :", X_train.iloc[0])
# Out:
# Before: hơi kém màu đúng
# After : hơi kém màu

# %%
vectorizer = TfidfVectorizer(
    max_features=20000,
    ngram_range=(1, 2),
    norm='l2'
)

X_train_tfidf = vectorizer.fit_transform(X_train)
X_dev_tfidf   = vectorizer.transform(X_dev)
X_test_tfidf  = vectorizer.transform(X_test)

print("TF-IDF shape:", X_train_tfidf.shape)
# Out:
# TF-IDF shape: (20591, 20000)

# %%
# =========================
# NAIVE BAYES
# =========================
nb_params = {"alpha": [0.01, 0.1, 0.5, 1.0]}

nb_grid = GridSearchCV(
    MultinomialNB(),
    nb_params,
    cv=5,
    scoring="f1_macro",
    n_jobs=-1
)

nb_grid.fit(X_train_tfidf, y_train)
nb_best = nb_grid.best_estimator_

print("Best NB params:", nb_grid.best_params_)
# Out:
# Best NB params: {'alpha': 0.1}

# %%
# =========================
# VISUALIZE NB
# =========================
import matplotlib.pyplot as plt

alphas = nb_grid.cv_results_['param_alpha'].data
scores = nb_grid.cv_results_['mean_test_score']

plt.figure()
plt.plot(alphas, scores, marker='o')

plt.xlabel("Alpha")
plt.ylabel("Macro F1 (CV)")
plt.title("Naive Bayes - Hyperparameter Tuning")

for i in range(len(alphas)):
    plt.text(alphas[i], scores[i], f"{scores[i]:.3f}")

plt.show()

# %%
# =========================
# SVM
# =========================
svm_params = {"C": [0.1, 1, 10]}

svm_grid = GridSearchCV(
    LinearSVC(),
    svm_params,
    cv=5,
    scoring="f1_macro",
    n_jobs=-1
)

svm_grid.fit(X_train_tfidf, y_train)
svm_best = svm_grid.best_estimator_

print("Best SVM params:", svm_grid.best_params_)
# Out:
# Best SVM params: {'C': 1}

# %%
# =========================
# VISUALIZE SVM
# =========================
C_values = svm_grid.cv_results_['param_C'].data
scores = svm_grid.cv_results_['mean_test_score']

plt.figure()
plt.plot(C_values, scores, marker='o')

plt.xlabel("C")
plt.ylabel("Macro F1 (CV)")
plt.title("SVM - Hyperparameter Tuning")

for i in range(len(C_values)):
    plt.text(C_values[i], scores[i], f"{scores[i]:.3f}")

plt.show()

# %%
# =========================
# RANDOM FOREST
# =========================
rf_params = {
    "n_estimators": [20, 50, 100, 200],
    "max_depth": [None, 10, 20]
}

rf_grid = GridSearchCV(
    RandomForestClassifier(random_state=42),
    rf_params,
    cv=5,
    scoring="f1_macro",
    n_jobs=-1
)

rf_grid.fit(X_train_tfidf, y_train)
rf_best = rf_grid.best_estimator_

print("Best RF params:", rf_grid.best_params_)
# Out:
# Best RF params: {'max_depth': None, 'n_estimators': 100}

# %%
# =========================
# VISUALIZE RANDOM FOREST 
# =========================
results = pd.DataFrame(rf_grid.cv_results_)

# lọc max_depth = None (thực chất là NaN)
filtered = results[results['param_max_depth'].isna()]

# convert kiểu dữ liệu
n_estimators = filtered['param_n_estimators'].astype(int)
scores = filtered['mean_test_score']

plt.figure()
plt.plot(n_estimators, scores, marker='o')

plt.xlabel("n_estimators")
plt.ylabel("Macro F1 (CV)")
plt.title("Random Forest (max_depth=None)")

for i in range(len(n_estimators)):
    plt.text(n_estimators.iloc[i], scores.iloc[i], f"{scores.iloc[i]:.3f}")

plt.show()

# %%
# =========================
# PROFESSIONAL EVALUATION FUNCTION
# =========================
def evaluate(model, X, y, name="Model"):
    y_pred = model.predict(X)

    acc = accuracy_score(y, y_pred)
    f1  = f1_score(y, y_pred, average="macro")

    # Title đẹp
    display(Markdown(f"## {name} Evaluation"))

    # ===== Summary Table =====
    summary_df = pd.DataFrame({
        "Metric": ["Accuracy", "Macro F1"],
        "Score": [round(acc, 4), round(f1, 4)]
    })

    display(summary_df.style.set_caption("Overall Performance"))

    # ===== Classification Report =====
    report = classification_report(y, y_pred, output_dict=True)
    report_df = pd.DataFrame(report).transpose()

    display(report_df.style
            .set_caption("Classification Report")
            .format("{:.4f}"))

    # ===== Confusion Matrix =====
    cm = confusion_matrix(y, y_pred)

    labels = sorted(list(set(y)))  # hoặc tự set: ["Negative","Neutral","Positive"]

    plt.figure()
    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        xticklabels=labels,
        yticklabels=labels
    )

    plt.title(f"Confusion Matrix - {name}")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")

    plt.show()

# %%
# =========================
# EVALUATE ON DEV
# =========================
evaluate(nb_best, X_dev_tfidf, y_dev, "Naive Bayes (Dev)")
# Out:
# ## Naive Bayes (Dev) Evaluation
# <style type="text/css">
# </style>
# <table id="T_e0af9">
#   <caption>Overall Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0af9_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_e0af9_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0af9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0af9_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_e0af9_row0_col1" class="data row0 col1" >0.684200</td>
#     </tr>
#     <tr>
#       <th id="T_e0af9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0af9_row1_col0" class="data row1 col0" >Macro F1</td>
#       <td id="T_e0af9_row1_col1" class="data row1 col1" >0.652000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f2b85">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2b85_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_f2b85_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_f2b85_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_f2b85_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2b85_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2b85_row0_col0" class="data row0 col0" >0.6960</td>
#       <td id="T_f2b85_row0_col1" class="data row0 col1" >0.7185</td>
#       <td id="T_f2b85_row0_col2" class="data row0 col2" >0.7071</td>
#       <td id="T_f2b85_row0_col3" class="data row0 col3" >1542.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2b85_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f2b85_row1_col0" class="data row1 col0" >0.5200</td>
#       <td id="T_f2b85_row1_col1" class="data row1 col1" >0.4203</td>
#       <td id="T_f2b85_row1_col2" class="data row1 col2" >0.4649</td>
#       <td id="T_f2b85_row1_col3" class="data row1 col3" >1111.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2b85_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f2b85_row2_col0" class="data row2 col0" >0.7509</td>
#       <td id="T_f2b85_row2_col1" class="data row2 col1" >0.8203</td>
#       <td id="T_f2b85_row2_col2" class="data row2 col2" >0.7841</td>
#       <td id="T_f2b85_row2_col3" class="data row2 col3" >1764.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2b85_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_f2b85_row3_col0" class="data row3 col0" >0.6842</td>
#       <td id="T_f2b85_row3_col1" class="data row3 col1" >0.6842</td>
#       <td id="T_f2b85_row3_col2" class="data row3 col2" >0.6842</td>
#       <td id="T_f2b85_row3_col3" class="data row3 col3" >0.6842</td>
#     </tr>
#     <tr>
#       <th id="T_f2b85_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_f2b85_row4_col0" class="data row4 col0" >0.6556</td>
#       <td id="T_f2b85_row4_col1" class="data row4 col1" >0.6531</td>
#       <td id="T_f2b85_row4_col2" class="data row4 col2" >0.6520</td>
#       <td id="T_f2b85_row4_col3" class="data row4 col3" >4417.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2b85_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_f2b85_row5_col0" class="data row5 col0" >0.6737</td>
#       <td id="T_f2b85_row5_col1" class="data row5 col1" >0.6842</td>
#       <td id="T_f2b85_row5_col2" class="data row5 col2" >0.6769</td>
#       <td id="T_f2b85_row5_col3" class="data row5 col3" >4417.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate(svm_best, X_dev_tfidf, y_dev, "SVM (Dev)")
# Out:
# ## SVM (Dev) Evaluation
# <style type="text/css">
# </style>
# <table id="T_902c4">
#   <caption>Overall Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_902c4_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_902c4_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_902c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_902c4_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_902c4_row0_col1" class="data row0 col1" >0.670400</td>
#     </tr>
#     <tr>
#       <th id="T_902c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_902c4_row1_col0" class="data row1 col0" >Macro F1</td>
#       <td id="T_902c4_row1_col1" class="data row1 col1" >0.635500</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_947ee">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_947ee_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_947ee_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_947ee_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_947ee_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_947ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_947ee_row0_col0" class="data row0 col0" >0.6809</td>
#       <td id="T_947ee_row0_col1" class="data row0 col1" >0.7348</td>
#       <td id="T_947ee_row0_col2" class="data row0 col2" >0.7068</td>
#       <td id="T_947ee_row0_col3" class="data row0 col3" >1542.0000</td>
#     </tr>
#     <tr>
#       <th id="T_947ee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_947ee_row1_col0" class="data row1 col0" >0.4847</td>
#       <td id="T_947ee_row1_col1" class="data row1 col1" >0.3852</td>
#       <td id="T_947ee_row1_col2" class="data row1 col2" >0.4293</td>
#       <td id="T_947ee_row1_col3" class="data row1 col3" >1111.0000</td>
#     </tr>
#     <tr>
#       <th id="T_947ee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_947ee_row2_col0" class="data row2 col0" >0.7487</td>
#       <td id="T_947ee_row2_col1" class="data row2 col1" >0.7937</td>
#       <td id="T_947ee_row2_col2" class="data row2 col2" >0.7705</td>
#       <td id="T_947ee_row2_col3" class="data row2 col3" >1764.0000</td>
#     </tr>
#     <tr>
#       <th id="T_947ee_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_947ee_row3_col0" class="data row3 col0" >0.6704</td>
#       <td id="T_947ee_row3_col1" class="data row3 col1" >0.6704</td>
#       <td id="T_947ee_row3_col2" class="data row3 col2" >0.6704</td>
#       <td id="T_947ee_row3_col3" class="data row3 col3" >0.6704</td>
#     </tr>
#     <tr>
#       <th id="T_947ee_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_947ee_row4_col0" class="data row4 col0" >0.6381</td>
#       <td id="T_947ee_row4_col1" class="data row4 col1" >0.6379</td>
#       <td id="T_947ee_row4_col2" class="data row4 col2" >0.6355</td>
#       <td id="T_947ee_row4_col3" class="data row4 col3" >4417.0000</td>
#     </tr>
#     <tr>
#       <th id="T_947ee_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_947ee_row5_col0" class="data row5 col0" >0.6586</td>
#       <td id="T_947ee_row5_col1" class="data row5 col1" >0.6704</td>
#       <td id="T_947ee_row5_col2" class="data row5 col2" >0.6624</td>
#       <td id="T_947ee_row5_col3" class="data row5 col3" >4417.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate(rf_best, X_dev_tfidf, y_dev, "Random Forest (Dev)")
# Out:
# ## Random Forest (Dev) Evaluation
# <style type="text/css">
# </style>
# <table id="T_a2b91">
#   <caption>Overall Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2b91_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_a2b91_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2b91_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2b91_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_a2b91_row0_col1" class="data row0 col1" >0.695500</td>
#     </tr>
#     <tr>
#       <th id="T_a2b91_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a2b91_row1_col0" class="data row1 col0" >Macro F1</td>
#       <td id="T_a2b91_row1_col1" class="data row1 col1" >0.649900</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7a2a1">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a2a1_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_7a2a1_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_7a2a1_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_7a2a1_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a2a1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a2a1_row0_col0" class="data row0 col0" >0.6852</td>
#       <td id="T_7a2a1_row0_col1" class="data row0 col1" >0.7905</td>
#       <td id="T_7a2a1_row0_col2" class="data row0 col2" >0.7341</td>
#       <td id="T_7a2a1_row0_col3" class="data row0 col3" >1542.0000</td>
#     </tr>
#     <tr>
#       <th id="T_7a2a1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a2a1_row1_col0" class="data row1 col0" >0.6094</td>
#       <td id="T_7a2a1_row1_col1" class="data row1 col1" >0.3384</td>
#       <td id="T_7a2a1_row1_col2" class="data row1 col2" >0.4352</td>
#       <td id="T_7a2a1_row1_col3" class="data row1 col3" >1111.0000</td>
#     </tr>
#     <tr>
#       <th id="T_7a2a1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a2a1_row2_col0" class="data row2 col0" >0.7308</td>
#       <td id="T_7a2a1_row2_col1" class="data row2 col1" >0.8373</td>
#       <td id="T_7a2a1_row2_col2" class="data row2 col2" >0.7804</td>
#       <td id="T_7a2a1_row2_col3" class="data row2 col3" >1764.0000</td>
#     </tr>
#     <tr>
#       <th id="T_7a2a1_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_7a2a1_row3_col0" class="data row3 col0" >0.6955</td>
#       <td id="T_7a2a1_row3_col1" class="data row3 col1" >0.6955</td>
#       <td id="T_7a2a1_row3_col2" class="data row3 col2" >0.6955</td>
#       <td id="T_7a2a1_row3_col3" class="data row3 col3" >0.6955</td>
#     </tr>
#     <tr>
#       <th id="T_7a2a1_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_7a2a1_row4_col0" class="data row4 col0" >0.6751</td>
#       <td id="T_7a2a1_row4_col1" class="data row4 col1" >0.6554</td>
#       <td id="T_7a2a1_row4_col2" class="data row4 col2" >0.6499</td>
#       <td id="T_7a2a1_row4_col3" class="data row4 col3" >4417.0000</td>
#     </tr>
#     <tr>
#       <th id="T_7a2a1_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_7a2a1_row5_col0" class="data row5 col0" >0.6844</td>
#       <td id="T_7a2a1_row5_col1" class="data row5 col1" >0.6955</td>
#       <td id="T_7a2a1_row5_col2" class="data row5 col2" >0.6774</td>
#       <td id="T_7a2a1_row5_col3" class="data row5 col3" >4417.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# =========================
# EVALUATE ON TEST
# =========================
evaluate(nb_best, X_test_tfidf, y_test, "Naive Bayes (Test)")
# Out:
# ## Naive Bayes (Test) Evaluation
# <style type="text/css">
# </style>
# <table id="T_dcc11">
#   <caption>Overall Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcc11_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_dcc11_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcc11_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dcc11_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_dcc11_row0_col1" class="data row0 col1" >0.700700</td>
#     </tr>
#     <tr>
#       <th id="T_dcc11_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dcc11_row1_col0" class="data row1 col0" >Macro F1</td>
#       <td id="T_dcc11_row1_col1" class="data row1 col1" >0.666400</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_59fd0">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59fd0_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_59fd0_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_59fd0_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_59fd0_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59fd0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59fd0_row0_col0" class="data row0 col0" >0.7189</td>
#       <td id="T_59fd0_row0_col1" class="data row0 col1" >0.7534</td>
#       <td id="T_59fd0_row0_col2" class="data row0 col2" >0.7357</td>
#       <td id="T_59fd0_row0_col3" class="data row0 col3" >1541.0000</td>
#     </tr>
#     <tr>
#       <th id="T_59fd0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_59fd0_row1_col0" class="data row1 col0" >0.5465</td>
#       <td id="T_59fd0_row1_col1" class="data row1 col1" >0.4169</td>
#       <td id="T_59fd0_row1_col2" class="data row1 col2" >0.4730</td>
#       <td id="T_59fd0_row1_col3" class="data row1 col3" >1113.0000</td>
#     </tr>
#     <tr>
#       <th id="T_59fd0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_59fd0_row2_col0" class="data row2 col0" >0.7524</td>
#       <td id="T_59fd0_row2_col1" class="data row2 col1" >0.8329</td>
#       <td id="T_59fd0_row2_col2" class="data row2 col2" >0.7906</td>
#       <td id="T_59fd0_row2_col3" class="data row2 col3" >1777.0000</td>
#     </tr>
#     <tr>
#       <th id="T_59fd0_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_59fd0_row3_col0" class="data row3 col0" >0.7007</td>
#       <td id="T_59fd0_row3_col1" class="data row3 col1" >0.7007</td>
#       <td id="T_59fd0_row3_col2" class="data row3 col2" >0.7007</td>
#       <td id="T_59fd0_row3_col3" class="data row3 col3" >0.7007</td>
#     </tr>
#     <tr>
#       <th id="T_59fd0_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_59fd0_row4_col0" class="data row4 col0" >0.6726</td>
#       <td id="T_59fd0_row4_col1" class="data row4 col1" >0.6677</td>
#       <td id="T_59fd0_row4_col2" class="data row4 col2" >0.6664</td>
#       <td id="T_59fd0_row4_col3" class="data row4 col3" >4431.0000</td>
#     </tr>
#     <tr>
#       <th id="T_59fd0_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_59fd0_row5_col0" class="data row5 col0" >0.6890</td>
#       <td id="T_59fd0_row5_col1" class="data row5 col1" >0.7007</td>
#       <td id="T_59fd0_row5_col2" class="data row5 col2" >0.6917</td>
#       <td id="T_59fd0_row5_col3" class="data row5 col3" >4431.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate(svm_best, X_test_tfidf, y_test, "SVM (Test)")
# Out:
# ## SVM (Test) Evaluation
# <style type="text/css">
# </style>
# <table id="T_56d3e">
#   <caption>Overall Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56d3e_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_56d3e_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56d3e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_56d3e_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_56d3e_row0_col1" class="data row0 col1" >0.692800</td>
#     </tr>
#     <tr>
#       <th id="T_56d3e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_56d3e_row1_col0" class="data row1 col0" >Macro F1</td>
#       <td id="T_56d3e_row1_col1" class="data row1 col1" >0.659200</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_c1b6c">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1b6c_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_c1b6c_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_c1b6c_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_c1b6c_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1b6c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1b6c_row0_col0" class="data row0 col0" >0.6941</td>
#       <td id="T_c1b6c_row0_col1" class="data row0 col1" >0.7670</td>
#       <td id="T_c1b6c_row0_col2" class="data row0 col2" >0.7287</td>
#       <td id="T_c1b6c_row0_col3" class="data row0 col3" >1541.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c1b6c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c1b6c_row1_col0" class="data row1 col0" >0.5453</td>
#       <td id="T_c1b6c_row1_col1" class="data row1 col1" >0.4106</td>
#       <td id="T_c1b6c_row1_col2" class="data row1 col2" >0.4685</td>
#       <td id="T_c1b6c_row1_col3" class="data row1 col3" >1113.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c1b6c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c1b6c_row2_col0" class="data row2 col0" >0.7571</td>
#       <td id="T_c1b6c_row2_col1" class="data row2 col1" >0.8053</td>
#       <td id="T_c1b6c_row2_col2" class="data row2 col2" >0.7805</td>
#       <td id="T_c1b6c_row2_col3" class="data row2 col3" >1777.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c1b6c_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_c1b6c_row3_col0" class="data row3 col0" >0.6928</td>
#       <td id="T_c1b6c_row3_col1" class="data row3 col1" >0.6928</td>
#       <td id="T_c1b6c_row3_col2" class="data row3 col2" >0.6928</td>
#       <td id="T_c1b6c_row3_col3" class="data row3 col3" >0.6928</td>
#     </tr>
#     <tr>
#       <th id="T_c1b6c_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_c1b6c_row4_col0" class="data row4 col0" >0.6655</td>
#       <td id="T_c1b6c_row4_col1" class="data row4 col1" >0.6610</td>
#       <td id="T_c1b6c_row4_col2" class="data row4 col2" >0.6592</td>
#       <td id="T_c1b6c_row4_col3" class="data row4 col3" >4431.0000</td>
#     </tr>
#     <tr>
#       <th id="T_c1b6c_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_c1b6c_row5_col0" class="data row5 col0" >0.6820</td>
#       <td id="T_c1b6c_row5_col1" class="data row5 col1" >0.6928</td>
#       <td id="T_c1b6c_row5_col2" class="data row5 col2" >0.6841</td>
#       <td id="T_c1b6c_row5_col3" class="data row5 col3" >4431.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate(rf_best, X_test_tfidf, y_test, "Random Forest (Test)")
# Out:
# ## Random Forest (Test) Evaluation
# <style type="text/css">
# </style>
# <table id="T_e2651">
#   <caption>Overall Performance</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2651_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_e2651_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2651_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2651_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_e2651_row0_col1" class="data row0 col1" >0.698300</td>
#     </tr>
#     <tr>
#       <th id="T_e2651_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e2651_row1_col0" class="data row1 col0" >Macro F1</td>
#       <td id="T_e2651_row1_col1" class="data row1 col1" >0.652600</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ae5ca">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae5ca_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_ae5ca_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_ae5ca_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_ae5ca_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae5ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae5ca_row0_col0" class="data row0 col0" >0.6910</td>
#       <td id="T_ae5ca_row0_col1" class="data row0 col1" >0.7936</td>
#       <td id="T_ae5ca_row0_col2" class="data row0 col2" >0.7387</td>
#       <td id="T_ae5ca_row0_col3" class="data row0 col3" >1541.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ae5ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae5ca_row1_col0" class="data row1 col0" >0.6258</td>
#       <td id="T_ae5ca_row1_col1" class="data row1 col1" >0.3396</td>
#       <td id="T_ae5ca_row1_col2" class="data row1 col2" >0.4403</td>
#       <td id="T_ae5ca_row1_col3" class="data row1 col3" >1113.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ae5ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ae5ca_row2_col0" class="data row2 col0" >0.7258</td>
#       <td id="T_ae5ca_row2_col1" class="data row2 col1" >0.8402</td>
#       <td id="T_ae5ca_row2_col2" class="data row2 col2" >0.7788</td>
#       <td id="T_ae5ca_row2_col3" class="data row2 col3" >1777.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ae5ca_level0_row3" class="row_heading level0 row3" >accuracy</th>
#       <td id="T_ae5ca_row3_col0" class="data row3 col0" >0.6983</td>
#       <td id="T_ae5ca_row3_col1" class="data row3 col1" >0.6983</td>
#       <td id="T_ae5ca_row3_col2" class="data row3 col2" >0.6983</td>
#       <td id="T_ae5ca_row3_col3" class="data row3 col3" >0.6983</td>
#     </tr>
#     <tr>
#       <th id="T_ae5ca_level0_row4" class="row_heading level0 row4" >macro avg</th>
#       <td id="T_ae5ca_row4_col0" class="data row4 col0" >0.6809</td>
#       <td id="T_ae5ca_row4_col1" class="data row4 col1" >0.6578</td>
#       <td id="T_ae5ca_row4_col2" class="data row4 col2" >0.6526</td>
#       <td id="T_ae5ca_row4_col3" class="data row4 col3" >4431.0000</td>
#     </tr>
#     <tr>
#       <th id="T_ae5ca_level0_row5" class="row_heading level0 row5" >weighted avg</th>
#       <td id="T_ae5ca_row5_col0" class="data row5 col0" >0.6886</td>
#       <td id="T_ae5ca_row5_col1" class="data row5 col1" >0.6983</td>
#       <td id="T_ae5ca_row5_col2" class="data row5 col2" >0.6799</td>
#       <td id="T_ae5ca_row5_col3" class="data row5 col3" >4431.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# =========================
# COMPARISON TABLE
# =========================
results = []

models = {
    "Naive Bayes": nb_best,
    "SVM": svm_best,
    "Random Forest": rf_best
}

for name, model in models.items():
    y_pred = model.predict(X_test_tfidf)
    
    acc = accuracy_score(y_test, y_pred)
    f1  = f1_score(y_test, y_pred, average="macro")
    
    results.append({
        "Model": name,
        "Accuracy": round(acc, 4),
        "Macro F1": round(f1, 4)
    })

results_df = pd.DataFrame(results)
results_df = results_df.sort_values(by="Macro F1", ascending=False)

results_df
# Out:
#            Model  Accuracy  Macro F1
# 0    Naive Bayes    0.7007    0.6664
# 1            SVM    0.6928    0.6592
# 2  Random Forest    0.6983    0.6526

# %%
models = results_df["Model"]
accuracy = results_df["Accuracy"]
f1_scores = results_df["Macro F1"]

x = np.arange(len(models))
width = 0.35

plt.figure()

plt.bar(x - width/2, accuracy, width, label="Accuracy")
plt.bar(x + width/2, f1_scores, width, label="Macro F1")

plt.xticks(x, models)
plt.ylabel("Score")
plt.title("Model Comparison")

# Hiển thị số
for i in range(len(models)):
    plt.text(x[i] - width/2, accuracy[i], f"{accuracy[i]:.3f}")
    plt.text(x[i] + width/2, f1_scores[i], f"{f1_scores[i]:.3f}")

plt.legend()
plt.show()

# %%
# =========================
# SAVE RESULTS
# =========================
results_df.to_excel("model_comparison.xlsx", index=False)
